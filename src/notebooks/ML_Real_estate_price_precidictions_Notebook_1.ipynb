# %% [markdown]
# # Machine Learning Project: ML_Real estate price predictions

# %% [markdown]
# ## Predict Real Estate Prices using an API requested to Idealista

# %% [markdown]
# By extracting data using the Idealista API, it will be possible to perform monthly searches and develop a model that allows for calculating updated property prices. The main objective is to analyze whether sales prices represent a favorable purchasing opportunity in **Asturias**. This will allow potential buyers to make more informed decisions in the real estate market.
#
# Search API lets you integrate property information published on idealista into your site or app.
#
# **https://developers.idealista.com/access-request**

# %% [markdown]
# ### 0. Extracting data using the Idealista API, defining the functions, parameters, URL, and first visualization of the dataset

# %%
# Importing
import base64
import requests as rq
import json
import pandas as pd

# %%
# Defining the function to get token
def get_token():    
    '''
    The function will return the customized token
    '''
    api_key = 'ucdqwx5t02bfrynufi0r7psnwb6fu11c'          # API key provided by Idealista
    secret = 'ZwjDHTCE9yWM'                               # Secret code provided by Idealista
    message = api_key + ":" + secret                      # Concatenating the encoded API key and the secret
    auth = "Basic " + base64.b64encode(message.encode("ascii")).decode("ascii")   # Encoding the message
    headers_1 = {"Authorization" : auth,
                   "Content-Type" : "application/x-www-form-urlencoded;charset=UTF-8"}   # Defining the headers
    data_1 = {"grant_type" : "client_credentials",      # Defining the request parameters
                  "scope" : "read"}
    r = rq.post("https://api.idealista.com/oauth/token",  # Requesting the API URL, headers and params
                      headers = headers_1,
                      data = data_1)
    token = json.loads(r.text)['access_token']            # Obtaining the custom token, in JSON format
    return token

# %%
# These are the parameters that will be used to filter the search.
base_url = 'https://api.idealista.com/3.5/'     # Resource URL
country = 'es'                                  # Countries (values: es (Spain), it (Italy), and pt(Portugal))                          
language = 'es'                                 # Language (values: es, it, pt, en, ca) 
max_items = '50'                                # 50 a maximum allowed per call set by Idealista
operation = 'sale'                              # Operation type (values: sale, rent) 
property_type = 'homes'                         # Type of property (values: homes, offices, premises, garages, bedrooms)
order = 'priceDown'                             # Allowed values by property_type: homes
center = '43.53573,-5.66152'                    # Geographic coordinates -> ASTURIAS (Gijon Center)
distance = '250000'                             # Maximum distance from the center (Gijon Center)
sort = 'desc'                                   # Sorting the found items
bankOffer = 'false'                             # If the owner is a bank
maxprice = '1000000'                            # Maximum price

# %%
# Defining the function to obtain the search URL for Sales in Gijon, Asturias

def define_url(operation = 'sale', country = 'es',language = 'es',max_items = '50',property_type = 'homes',order = 'priceDown',
                      center = '43.53573,-5.66152',distance = '250000',sort = 'desc',bankOffer = 'false',maxprice = '1000000'):
    '''
    These are the parameters that will be used to filter the search. So, the function will combine these parameters with the url to generate our 
    own search url parameters: 

    base_url = 'https://api.idealista.com/3.5/'     # Resource URL
    country = 'es'                                  # Countries (values: es (Spain), it (Italy), and pt(Portugal))                          
    language = 'es'                                 # Language (values: es, it, pt, en, ca) 
    max_items = '50'                                # 50 a maximum allowed per call set by Idealista
    operation = 'sale'                              # Operation type (values: sale, rent) 
    property_type = 'homes'                         # Type of property (values: homes, offices, premises, garages, bedrooms)
    order = 'priceDown'                             # Allowed values by property_type: homes
    center = '43.53573,-5.66152'                    # Geographic coordinates -> ASTURIAS (Gijon Center)
    distance = '250000'                             # Maximum distance from the center (Gijon Center)
    sort = 'desc'                                   # Sorting the found items
    bankOffer = 'false'                             # If the owner is a bank
    maxprice = '1000000'                            # Maximum price

    '''
    url = ('https://api.idealista.com/3.5/'  +      
           country +
           '/search?operation=' + operation +
           '&maxItems=' + max_items +
           '&order=' + order +
           '&center=' + center +
           '&distance=' + distance +
           '&propertyType=' + property_type +
           '&sort=' + sort + 
           '&numPage=%d' +
           '&maxPrice=' + maxprice +
           '&language=' + language)
    
    return url

# %%
define_url('sale')
# Out:
# 'https://api.idealista.com/3.5/es/search?operation=sale&maxItems=50&order=priceDown&center=43.53573,-5.66152&distance=250000&propertyType=homes&sort=desc&numPage=%d&maxPrice=1000000&language=es'

# %%
url = define_url()

# %%
# Defining the API search
def search_api(url):  
    '''
    The generated token and URL will be used by the function, which will return the search results.
    '''
    token = get_token()                         #  Getting the custom token

    headers = {'Content-Type': 'Content-Type: multipart/form-data;',   # Defining the search headers 
               'Authorization' : 'Bearer ' + token}

    content = rq.post(url, headers = headers)   # Returning the content from the request

    result = json.loads(content.text)           # Transforming the result as a json file   

    return result

# %%
# Performing pagination of the first query, page 1
pagination = 1
first_query_url = url %(pagination)

# %%
# Performing the search with the paginated URL
results = search_api(first_query_url)

# %%
print(results)
# Out:
# {'elementList': [{'propertyCode': '106100857', 'thumbnail': 'https://img4.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/73/9d/61/1304374723.webp', 'externalReference': 'REF_31176', 'numPhotos': 36, 'price': 9500.0, 'priceInfo': {'price': {'amount': 9500.0, 'currencySuffix': '€', 'priceDropInfo': {'formerPrice': 18500.0, 'priceDropValue': 9000, 'priceDropPercentage': 49}}}, 'propertyType': 'chalet', 'operation': 'sale', 'size': 65.0, 'rooms': 2, 'bathrooms': 1, 'address': 'AL SANTA EUGENIA, 7', 'province': 'Asturias', 'municipality': 'Villaviciosa', 'district': 'Parroquias surorientales', 'country': 'es', 'latitude': 43.4678584, 'longitude': -5.359872, 'showAddress': False, 'url': 'https://www.idealista.com/inmueble/106100857/', 'distance': '25471', 'description': 'Haz tu oferta! Asesoramiento con todas las facilidades para la reforma incluido  Exclusivo ventanal orientación SUR con vistas al paraíso natural en este tranquilo pueblo tradicional con acceso recientemente rehabilitado a solo 10 minutos de Villaviciosa  Este encantador lugar a solo 10 minutos de Villaviciosa con vistas panorámicas a un entorno natural privilegiado como son los verdes paisajes asturianos te brinda la comodidad de tener todos los servicios a tu alcance a solo 10 minutos en coche. Su cuidada iglesia, parque infantil y plaza la hacen un entorno ideal para disfrutar del silencio. El acceso ha sido recientemente rehabilitado, lo que garantiza comodidad y seguridad.  Esta antigua casa de 3 plantas son 60 metros cuadrados con un diseño tradicional y rústico, ofrece un gran potencial para ser reformada y convertida en el refugio perfecto para escapar del ajetreo de la ciudad. Cuenta con agua y luz al corriente de pago, el saneamiento solo requiere el enganche lo que facilita la reforma. Imagina entrar en la casa y ser recibido por un ambiente acogedor lleno de posibilidades con una distribución diáfana en la que podrás diseñar el espacio a tu gusto y crear el hogar de tus sueños. Las vistas a la naturaleza desde los ventanales te conectarán con el entorno y te brindarán una sensación de paz y tranquilidad brutal. ¡No pierdas la oportunidad de tener tu propio refugio en el encantador entorno asturiano!', 'hasVideo': True, 'status': 'renew', 'newDevelopment': False, 'priceByArea': 146.0, 'change': {}, 'detailedType': {'typology': 'chalet', 'subTypology': 'independantHouse'}, 'suggestedTexts': {'subtitle': 'Parroquias surorientales, Villaviciosa', 'title': 'Casa independiente en Al Santa Eugenia, 7'}, 'hasPlan': True, 'has3DTour': False, 'has360': False, 'hasStaging': False, 'highlight': {'groupDescription': 'Destacado'}, 'savedAd': {}, 'notes': [], 'topNewDevelopment': False, 'topPlus': False}, {'propertyCode': '106567113', 'thumbnail': 'https://img4.idealista.com/blur/WEB_LISTING/90/id.pro.es.image.master/8c/36/bb/1287000512.webp', 'externalReference': 'Myo', 'numPhotos': 20, 'price': 150000.0, 'priceInfo': {'price': {'amount': 150000.0, 'currencySuffix': '€', 'priceDropInfo': {'formerPrice': 290000.0, 'priceDropValue': 140000, 'priceDropPercentage': 48}}}, 'propertyType': 'countryHouse', 'operation': 'sale', 'size': 290.0, 'rooms': 1, 'bathrooms': 0, 'address': 'Valdeolea', 'province': 'Cantabria', 'municipality': 'Valdeolea', 'country': 'es', 'latitude': 42.877086, 'longitude': -4.1625006, 'showAddress': False, 'url': 'https://www.idealista.com/inmueble/106567113/', 'distance': '141850', 'description': 'Y en construcción en el valle de Valderredible. Posibilidad de muchísimos metros o menos, esta vivienda nos la podemos diseñar a nuestro antojo, cuenta con un hermoso jardín en el que hay un pozo original de los que antiguamente abastecían de agua a las casas. Están hechas las divisiones en tres alturas, dispone de hornera como elemento antiguo característico de la zona. En un valle tranquilo y rodeado de una espectacular naturaleza tenemos este inmueble esperando a que nos diseñe su proyecto de hogar.', 'hasVideo': False, 'status': 'renew', 'newD ...

# %%
# Defining the total number of pages available, given that we can only extract up to 50 results per page.
total_pages = results['totalPages']

# %%
total_pages
# Out:
# 805

# %%
def results_to_df(results):
    '''
    The following function will save the JSON results as a DataFrame and return the resulting DataFrame.
    '''
    df = pd.DataFrame.from_dict(results['elementList'])

    return df

# %%
def concat_df(df, df_total):
    '''
    This function takes the primary DataFrame (df_tot) and concatenates it with the specified individual dataframe, returning the updated main DataFrame.
    '''
    pd.concat([df_total,df])
    
    return df_total

# %%
# Saving the results in a DataFrame
df = results_to_df(results)

# %%
df
# Out:
#    propertyCode                                          thumbnail  \
# 0     106100857  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 1     106567113  https://img4.idealista.com/blur/WEB_LISTING/90...
# 2      97273645  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 3     106463395  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 4     100774492  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 5      89087743  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 6     105322146  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 7      28756787  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 8      33499727  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 9     106110102  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 10    105411647  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 11    107314115  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 12    106826209  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 13    104811151  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 14     98703315  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 15    106110133  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 16    102339218  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 17    105540308  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 18    106597971  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 19    107614327  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 20     87801981  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 21    104407660  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 22     98077021  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 23     96572351  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 24    107513251  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 25    102407436  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 26    107022810  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 27     98646482  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 28    101595253  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 29     99983687  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 30    107538355  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 31    101510764  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 32    105950928  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 33     99235765  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 34    105939276  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 35    102567092  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 36     96557919  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 37    106716546  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 38    101532863  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 39    106707412  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 40    107593529  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 41    104167338  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 42     82948156  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 43    105594954  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 44    107565934  https://img4.idealista.com/blur/WEB_LISTING/90...
# 45    103731578  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 46    105226937  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 47    106463189  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 48    107347136  https://img4.idealista.com/blur/WEB_LISTING/0/...
# 49     99422723  https://img4.idealista.com/blur/WEB_LISTING/0/...
#
#          externalReference  numPhotos     price  \
# 0                REF_31176         36    9500.0
# 1                      Myo         20  150000.0
# 2                      NaN          8   60000.0
# 3                    62659          4   35000.0
# 4               0050124471          1   64700.0
# 5   2041##2041_0114_PE0001          4    9900.0
# 6                    08474         33   55000.0
# 7                     4237         13   39900.0
# 8               0034752278          1   14900.0
# 9               0033747036          1   26100.0
# 10              0044115215          1   15300.0
# 11              3421-09964         43  135000.0
# 12                     NaN         48  150000.0
# 13                    1021         16   59000.0
# 14              0046823972          4   23200.0
# 15              0044519672          2   25100.0
# 16                     NaN         22   28000.0
# 17              0044085159          1   77800.0
# 18                  150028         15   28000.0
# 19                     NaN        115  160000.0
# 20             19/CA/503/V         29  950000.0
# 21              0046853859          1   23800.0
# 22              0046863036          2   30400.0
# 23                    5531          7   29000.0
# 24                   30307         11   25000.0
# 25                 C000704         35   59900.0
# 26         CASA VILLABASTA         15   10000.0
# 27                   5224A          2    3900.0
# 28                 C000960         23   20000.0
# 29                  CV-775         19   95000.0
# 30               INMO00142          4   65000.0
# 31                    2602         11   36000.0
# 32                 C010180         76  269000.0
# 33                  740474         16   90000.0
# 34                 C001009         53  269000.0
# 35                     NaN         25   16000.0
# 36           CK-03830-0001          4   19000.0
# 37                W-02XXL9         62  457500.0
# 38              3471-14338         32   21285.0
# 39           15LDSANTANDER         14  135000.0
# 40               049.32857         34   99000.0
# 41                  Legión         24  115000.0
# 42                     NaN         45   64000.0
# 43           shgordoncillo         35   94500.0
# 44                     NaN         19  158000.0
# 45                85842984         13  350000.0
# 46                 1101046         20   40000.0
# 47                   62658          1   60300.0
# 48                CAR-0401         26   79900.0
# 49                 CAS_491         27  285000.0
#
#                                             priceInfo  propertyType operation  \
# 0   {'price': {'amount': 9500.0, 'currencySuffix':...        chalet      sale
# 1   {'price': {'amount': 150000.0, 'currencySuffix...  countryHouse      sale
# 2   {'price': {'amount': 60000.0, 'currencySuffix'...          flat      sale
# 3   {'price': {'amount': 35000.0, 'currencySuffix'...        chalet      sale
# 4   {'price': {'amount': 64700.0, 'currencySuffix'...          flat      sale
# 5   {'price': {'amount': 9900.0, 'currencySuffix':...          flat      sale
# 6   {'price': {'amount': 55000.0, 'currencySuffix'...  countryHouse      sale
# 7   {'price': {'amount': 39900.0, 'currencySuffix'...          flat      sale
# 8   {'price': {'amount': 14900.0, 'currencySuffix'...        chalet      sale
# 9   {'price': {'amount': 26100.0, 'currencySuffix'...        chalet      sale
# 10  {'price': {'amount': 15300.0, 'currencySuffix'...          flat      sale
# 11  {'price': {'amount': 135000.0, 'currencySuffix...          flat      sale
# 12  {'price': {'amount': 150000.0, 'currencySuffix...        chalet      sale
# 13  {'price': {'amount': 59000.0, 'currencySuffix'...        chalet      sale
# 14  {'price': {'amount': 23200.0, 'currencySuffix'...        chalet      sale
# 15  {'price': {'amount': 25100.0, 'currencySuffix'...          flat      sale
# 16  {'price': {'amount': 28000.0, 'currencySuffix'...        chalet      sale
# 17  {'price': {'amount': 77800.0, 'currencySuffix'...        chalet      sale
# 18  {'price': {'amount': 28000.0, 'currencySuffix'...        chalet      sale
# 19  {'price': {'amount': 160000.0, 'currencySuffix...        chalet      sale
# 20  {'price': {'amount': 950000.0, 'currencySuffix...        chalet      sale
# 21  {'price': {'amount': 23800.0, 'currencySuffix'...        chalet      sale
# 22  {'price': {'amount': 30400.0, 'currencySuffix'...        chalet      sale
# 23  {'price': {'amount': 29000.0, 'currencySuffix'...        chalet      sale
# 24  {'price': {'amount': 25000.0, 'currencySuffix'...  countryHouse      sale
# 25  {'price': {'amount': 59900.0, 'currencySuffix'...  countryHouse      sale
# 26  {'price': {'amount': 10000.0, 'currencySuffix'...        chalet      sale
# 27  {'price': {'amount': 3900.0, 'currencySuffix':...        chalet      sale
# 28  {'price': {'amount': 20000.0, 'currencySuffix'...        chalet      sale
# 29  {'price': {'amount': 95000.0, 'currencySuffix'...  countryHouse      sale
# 30  {'price': {'amount': 65000.0, 'currencySuffix'...        chalet      sale
# 31  {'price': {'amount': 36000.0, 'currencySuffix'...          flat      sale
# 32  {'price': {'amount': 269000.0, 'currencySuffix...        chalet      sale
# 33  {'price': {'amount': 90000.0, 'currencySuffix'...          flat      sale
# 34  {'price': {'amount': 269000.0, 'currencySuffix...        chalet      sale
# 35  {'price': {'amount': 16000.0, 'currencySuffix'...  countryHouse      sale
# 36  {'price': {'amount': 19000.0, 'currencySuffix'...        chalet      sale
# 37  {'price': {'amount': 457500.0, 'currencySuffix...  countryHouse      sale
# 38  {'price': {'amount': 21285.0, 'currencySuffix'...  countryHouse      sale
# 39  {'price': {'amount': 135000.0, 'currencySuffix...          flat      sale
# 40  {'price': {'amount': 99000.0, 'currencySuffix'...        chalet      sale
# 41  {'price': {'amount': 115000.0, 'currencySuffix...          flat      sale
# 42  {'price': {'amount': 64000.0, 'currencySuffix'...          flat      sale
# 43  {'price': {'amount': 94500.0, 'currencySuffix'...  countryHouse      sale
# 44  {'price': {'amount': 158000.0, 'currencySuffix...        chalet      sale
# 45  {'price': {'amount': 350000.0, 'currencySuffix...  countryHouse      sale
# 46  {'price': {'amount': 40000.0, 'currencySuffix'...        chalet      sale
# 47  {'price': {'amount': 60300.0, 'currencySuffix'...          flat      sale
# 48  {'price': {'amount': 79900.0, 'currencySuffix'...          flat      sale
# 49  {'price': {'amount': 285000.0, 'currencySuffix...        chalet      sale
#
#       size  rooms  ...  hasStaging                          highlight savedAd  \
# 0     65.0      2  ...       False  {'groupDescription': 'Destacado'}      {}
# 1    290.0      1  ...       False                                NaN      {}
# 2    283.0      1  ...       False                                NaN      {}
# 3    537.0      4  ...       False                                NaN      {}
# 4     96.0      3  ...       False                                NaN      {}
# 5     45.0      1  ...       False                                NaN      {}
# 6   1051.0      1  ...       False                                NaN      {}
# 7     70.0      2  ...       False  {'groupDescription': 'Destacado'}      {}
# 8     38.0      2  ...       False                                NaN      {}
# 9    120.0      4  ...       False                                NaN      {}
# 10    59.0      3  ...       False                                NaN      {}
# 11    90.0      3  ...       False                                NaN      {}
# 12   600.0      4  ...       False                                NaN      {}
# 13   306.0      1  ...       False                                NaN      {}
# 14   104.0      3  ...       False                                NaN      {}
# 15    37.0      1  ...       False                                NaN      {}
# 16   250.0      4  ...       False                                NaN      {}
# 17   172.0      3  ...       False                                NaN      {}
# 18   112.0      3  ...       False  {'groupDescription': 'Destacado'}      {}
# 19   190.0      6  ...       False                                NaN      {}
# 20   952.0      5  ...       False                                NaN      {}
# 21    76.0      3  ...       False                                NaN      {}
# 22   216.0      3  ...       False                                NaN      {}
# 23   176.0      4  ...       False                                NaN      {}
# 24    98.0      3  ...       False                                NaN      {}
# 25   490.0      5  ...       False                                NaN      {}
# 26   222.0      6  ...       False                                NaN      {}
# 27   198.0      1  ...       False                                NaN      {}
# 28   252.0      2  ...       False                                NaN      {}
# 29   204.0      6  ...       False                                NaN      {}
# 30   568.0      4  ...       False                                NaN      {}
# 31    63.0      3  ...       False                                NaN      {}
# 32   495.0      5  ...       False                                NaN      {}
# 33   167.0      6  ...       False                                NaN      {}
# 34   400.0      5  ...       False                                NaN      {}
# 35   119.0      3  ...       False                                NaN      {}
# 36   120.0      3  ...       False                                NaN      {}
# 37   915.0     10  ...       False  {'groupDescription': 'Destacado'}      {}
# 38   192.0      3  ...       False  {'groupDescription': 'Destacado'}      {}
# 39    92.0      3  ...       False                                NaN      {}
# 40   100.0      3  ...       False                                NaN      {}
# 41   111.0      4  ...       False  {'groupDescription': 'Destacado'}      {}
# 42   105.0      3  ...       False                                NaN      {}
# 43  1175.0      5  ...       False                                NaN      {}
# 44   430.0      4  ...       False                                NaN      {}
# 45   420.0      4  ...       False  {'groupDescription': 'Destacado'}      {}
# 46   144.0      4  ...       False                                NaN      {}
# 47   124.0      4  ...       False                                NaN      {}
# 48    99.0      3  ...       False  {'groupDescription': 'Destacado'}      {}
# 49   600.0      5  ...       False  {'groupDescription': 'Destacado'}      {}
#
#    notes topNewDevelopment topPlus  floor  exterior  hasLift  \
# 0     []             False   False    NaN       NaN      NaN
# 1     []             False   False    NaN       NaN      NaN
# 2     []             False   False     en      True    False
# 3     []             False   False    NaN       NaN      NaN
# 4     []             False   False    NaN       NaN      NaN
# 5     []             False   False    NaN       NaN      NaN
# 6     []             False   False     bj       NaN      NaN
# 7     []             False   False      1      True    False
# 8     []             False   False    NaN       NaN      NaN
# 9     []             False   False    NaN       NaN      NaN
# 10    []             False   False    NaN       NaN      NaN
# 11    []             False   False      2      True    False
# 12    []             False   False    NaN       NaN      NaN
# 13    []             False   False    NaN       NaN      NaN
# 14    []             False   False    NaN       NaN      NaN
# 15    []             False   False    NaN       NaN      NaN
# 16    []             False   False    NaN       NaN      NaN
# 17    []             False   False    NaN       NaN      NaN
# 18    []             False   False    NaN       NaN      NaN
# 19    []             False   False    NaN       NaN      NaN
# 20    []             False   False    NaN       NaN      NaN
# 21    []             False   False    NaN       NaN      NaN
# 22    []             False   False    NaN       NaN      NaN
# 23    []             False   False    NaN       NaN      NaN
# 24    []             False   False    NaN       NaN      NaN
# 25    []             False   False    NaN       NaN      NaN
# 26    []             False   False    NaN       NaN      NaN
# 27    []             False   False    NaN       NaN      NaN
# 28    []             False   False    NaN       NaN      NaN
# 29    []             False   False    NaN       NaN      NaN
# 30    []             False   False    NaN       NaN      NaN
# 31    []             False   False      4      True    False
# 32    []             False   False    NaN       NaN      NaN
# 33    []             False   False     bj      True    False
# 34    []             False   False    NaN       NaN      NaN
# 35    []             False   False    NaN       NaN      NaN
# 36    []             False   False    NaN       NaN      NaN
# 37    []             False   False    NaN       NaN      NaN
# 38    []             False   False    NaN       NaN      NaN
# 39    []             False   False      1     False     True
# 40    []             False   False    NaN       NaN      NaN
# 41    []             False   False      4      True     True
# 42    []             False   False      3      True    False
# 43    []             False   False     bj       NaN      NaN
# 44    []             False   False    NaN       NaN      NaN
# 45    []             False   False     bj       NaN      NaN
# 46    []             False   False    NaN       NaN      NaN
# 47    []             False   False      1      True     True
# 48    []             False   False      3      True    False
# 49    []             False   False    NaN       NaN      NaN
#
#                                          parkingSpace
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 33  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 34  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 43  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 44  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 45                                                NaN
# 46  {'hasParkingSpace': True, 'isParkingSpaceInclu...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
# [50 rows x 42 columns]

# %%
# Creating a copy of the DataFrame 'df' and storing it in the variable 'df_total'.
df_total = df.copy()

# %%
# This function allows you to paginate through property search results in the Idealista API, collecting all the data into a single DataFrame 
# for further analysis or use.

for i in range(1,total_pages):
    url = ('https://api.idealista.com/3.5/'+country+'/search?operation='+operation+#"&locale="+locale+
           '&maxItems='+max_items+
           '&order='+order+
           '&center='+center+
           '&distance='+distance+
           '&propertyType='+property_type+
           '&sort='+sort+ 
           '&numPage=%s'+
           '&language='+language) %(i)  
    results = search_api(url) 
    df = pd.DataFrame.from_dict(results['elementList'])
    df_total = pd.concat([df_total,df])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[146], line 14
#       4 for i in range(1,total_pages):
#       5     url = ('https://api.idealista.com/3.5/'+country+'/search?operation='+operation+#"&locale="+locale+
#       6            '&maxItems='+max_items+
#       7            '&order='+order+
#    (...)
#      12            '&numPage=%s'+
#      13            '&language='+language) %(i)
# ---> 14     results = search_api(url)
#      15     df = pd.DataFrame.from_dict(results['elementList'])
#      16     df_total = pd.concat([df_total,df])
#
# Cell In[132], line 13, in search_api(url)
#       8 headers = {'Content-Type': 'Content-Type: multipart/form-data;',   # Defining the search headers
#       9            'Authorization' : 'Bearer ' + token}
#      11 content = rq.post(url, headers = headers)   # Returning the content from the request
# ---> 13 result = json.loads(content.text)           # Transforming the result as a json file
#      15 return result
#
# File c:\Users\argpe\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\argpe\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\argpe\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
'''
The error shown above is due to the API only allows a maximum of 100 searches per month, the system displays the error mentioned above.
El error mostrado arriba se debe a que la API solo permite un máximo de 100 búsquedas al mes, el sistema muestra el error mencionado anteriormente.
'''

# %% [markdown]
# ========================================================================================================

# %% [markdown]
# ### 1. Saving the Dataset

# %%
# Saving dataset
df_total.to_csv('C:/Users/argpe/REPO_PRUEBA_2/ML_Real_estate_price_predictions/src/data_sample/idealista_astur.csv')

# %%
'''
Notebook_1:
The dataset 'df total' was saved
'''
